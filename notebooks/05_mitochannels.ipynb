# %%
import pandas as pd


mitocarta = pd.read_excel("../data/raw/Human.MitoCarta3.0.xls",sheet_name="A Human MitoCarta3.0").drop(["HumanGeneID","MouseOrthologGeneID"],axis=1).set_index("Symbol")
mitocarta
# Out:
#                                        Synonyms  \
# Symbol
# CYC1                               MC3DN6|UQCR4
# SDHB           CWS2|IP|PGL4|SDH|SDH1|SDH2|SDHIP
# COQ7                    CAT5|CLK-1|CLK1|COQ10D8
# SDHA              CMD1GG|FP|PGL5|SDH1|SDH2|SDHF
# UQCRC1                       D3S3191|QCR1|UQCR1
# ...                                         ...
# NAT8L                      CML3|NACED|NAT8-LIKE
# MCCD1                                         -
# PIGBOS1                                 HP06981
# HTD2                                          -
# RP11_469A15.2                                 -
#
#                                                      Description  \
# Symbol
# CYC1                                               cytochrome c1
# SDHB           succinate dehydrogenase complex iron sulfur su...
# COQ7                                    coenzyme Q7, hydroxylase
# SDHA           succinate dehydrogenase complex flavoprotein s...
# UQCRC1           ubiquinol-cytochrome c reductase core protein 1
# ...                                                          ...
# NAT8L                                 N-acetyltransferase 8 like
# MCCD1                         mitochondrial coiled-coil domain 1
# PIGBOS1                                   PIGB opposite strand 1
# HTD2                    hydroxyacyl-thioester dehydratase type 2
# RP11_469A15.2                                      RP11_469A15.2
#
#               MitoCarta3.0_List  \
# Symbol
# CYC1               MitoCarta3.0
# SDHB               MitoCarta3.0
# COQ7               MitoCarta3.0
# SDHA               MitoCarta3.0
# UQCRC1             MitoCarta3.0
# ...                         ...
# NAT8L              MitoCarta3.0
# MCCD1              MitoCarta3.0
# PIGBOS1            MitoCarta3.0
# HTD2               MitoCarta3.0
# RP11_469A15.2      MitoCarta3.0
#
#                                            MitoCarta3.0_Evidence  \
# Symbol
# CYC1           literature, APEX_IMS, APEX_matrix, targetP sig...
# SDHB           literature, APEX_matrix, targetP signal+, yeas...
# COQ7           literature, targetP signal+, yeast mito homolo...
# SDHA           literature, APEX_matrix, targetP signal+, yeas...
# UQCRC1         literature, APEX_matrix, targetP signal+, yeas...
# ...                                                          ...
# NAT8L                                                 literature
# MCCD1                                                    manual
# PIGBOS1                                               literature
# HTD2                                                  literature
# RP11_469A15.2                                         literature
#
#               MitoCarta3.0_SubMitoLocalization  \
# Symbol
# CYC1                                       MIM
# SDHB                                       MIM
# COQ7                                       MIM
# SDHA                                       MIM
# UQCRC1                                     MIM
# ...                                        ...
# NAT8L                                 Membrane
# MCCD1                                  unknown
# PIGBOS1                                    MOM
# HTD2                                    Matrix
# RP11_469A15.2                              MIM
#
#                                        MitoCarta3.0_MitoPathways  \
# Symbol
# CYC1           OXPHOS > Complex III > CIII subunits | Metabol...
# SDHB           OXPHOS > Complex II > CII subunits | Metabolis...
# COQ7           Metabolism > Metals and cofactors > Coenzyme Q...
# SDHA           OXPHOS > Complex II > CII subunits | Metabolis...
# UQCRC1         Protein import, sorting and homeostasis > Prot...
# ...                                                          ...
# NAT8L          Metabolism > Amino acid metabolism > Glutamate...
# MCCD1                                                          0
# PIGBOS1        Mitochondrial dynamics and surveillance > Orga...
# HTD2           Metabolism > Lipid metabolism > Type II fatty ...
# RP11_469A15.2                                                NaN
#
#                                                  TrainingDataset  \
# Symbol
# CYC1                                                       Tmito
# SDHB                                                       Tmito
# COQ7                                                       Tmito
# SDHA                                                       Tmito
# UQCRC1                                                     Tmito
# ...                                                          ...
# NAT8L                                             Tpossible_mito
# MCCD1                                             Tpossible_mito
# PIGBOS1                     NA - newly added to NCBI Entrez Gene
# HTD2                        NA - newly added to NCBI Entrez Gene
# RP11_469A15.2  NA - newly define mitochondrial protein (forme...
#
#                MitoCarta2.0_Score  MitoCarta2.0_FDR  MitoCarta2.0_List  ...  \
# Symbol                                                                  ...
# CYC1                      43.6442             0.000                1.0  ...
# SDHB                      43.2272             0.000                1.0  ...
# COQ7                      43.1028             0.000                1.0  ...
# SDHA                      42.9701             0.000                1.0  ...
# UQCRC1                    42.9037             0.000                1.0  ...
# ...                           ...               ...                ...  ...
# NAT8L                    -10.6961             0.887                0.0  ...
# MCCD1                    -10.8297             0.921                0.0  ...
# PIGBOS1                       NaN               NaN                NaN  ...
# HTD2                          NaN               NaN                NaN  ...
# RP11_469A15.2                 NaN               NaN                NaN  ...
#
#               liver_total_peak_intensity_log10  \
# Symbol
# CYC1                                      10.0
# SDHB                                      10.2
# COQ7                                       9.0
# SDHA                                      10.5
# UQCRC1                                    10.0
# ...                                        ...
# NAT8L                                      NaN
# MCCD1                                      NaN
# PIGBOS1                                    NaN
# HTD2                                       NaN
# RP11_469A15.2                              NaN
#
#               heart_total_peak_intensity_log10  \
# Symbol
# CYC1                                      10.4
# SDHB                                      10.3
# COQ7                                       8.6
# SDHA                                      10.7
# UQCRC1                                    10.8
# ...                                        ...
# NAT8L                                      NaN
# MCCD1                                      NaN
# PIGBOS1                                    NaN
# HTD2                                       NaN
# RP11_469A15.2                              NaN
#
#               skeletalmuscle_total_peak_intensity_log10  \
# Symbol
# CYC1                                                9.8
# SDHB                                                9.2
# COQ7                                                8.7
# SDHA                                               10.6
# UQCRC1                                             10.3
# ...                                                 ...
# NAT8L                                               NaN
# MCCD1                                               NaN
# PIGBOS1                                             NaN
# HTD2                                                NaN
# RP11_469A15.2                                       NaN
#
#                adipose_total_peak_intensity_log10  \
# Symbol
# CYC1                                         10.1
# SDHB                                         10.1
# COQ7                                          8.8
# SDHA                                         10.6
# UQCRC1                                       10.1
# ...                                           ...
# NAT8L                                         NaN
# MCCD1                                         NaN
# PIGBOS1                                       NaN
# HTD2                                          NaN
# RP11_469A15.2                                 NaN
#
#                smallintestine_total_peak_intensity_log10  \
# Symbol
# CYC1                                                10.2
# SDHB                                                10.3
# COQ7                                                 8.6
# SDHA                                                10.7
# UQCRC1                                              10.6
# ...                                                  ...
# NAT8L                                                NaN
# MCCD1                                                NaN
# PIGBOS1                                              NaN
# HTD2                                                 NaN
# RP11_469A15.2                                        NaN
#
#               largeintestine_total_peak_intensity_log10  \
# Symbol
# CYC1                                               10.2
# SDHB                                                9.9
# COQ7                                                9.0
# SDHA                                               10.6
# UQCRC1                                             10.2
# ...                                                 ...
# NAT8L                                               NaN
# MCCD1                                               NaN
# PIGBOS1                                             NaN
# HTD2                                                NaN
# RP11_469A15.2                                       NaN
#
#                stomach_total_peak_intensity_log10  \
# Symbol
# CYC1                                         10.0
# SDHB                                          9.9
# COQ7                                          8.7
# SDHA                                         10.5
# UQCRC1                                       10.3
# ...                                           ...
# NAT8L                                         NaN
# MCCD1                                         NaN
# PIGBOS1                                       NaN
# HTD2                                          NaN
# RP11_469A15.2                                 NaN
#
#                placenta_total_peak_intensity_log10  \
# Symbol
# CYC1                                          10.0
# SDHB                                          10.1
# COQ7                                           8.3
# SDHA                                          10.4
# UQCRC1                                        10.2
# ...                                            ...
# NAT8L                                          NaN
# MCCD1                                          NaN
# PIGBOS1                                        NaN
# HTD2                                           NaN
# RP11_469A15.2                                  NaN
#
#               testis_total_peak_intensity_log10  \
# Symbol
# CYC1                                        9.8
# SDHB                                        9.9
# COQ7                                        8.3
# SDHA                                       10.4
# UQCRC1                                      9.9
# ...                                         ...
# NAT8L                                       NaN
# MCCD1                                       NaN
# PIGBOS1                                     NaN
# HTD2                                        NaN
# RP11_469A15.2                               NaN
#
#               HPA_Main_Location_2020 (Reliability)
# Symbol
# CYC1                      Mitochondria (Supported)
# SDHB                      Mitochondria (Supported)
# COQ7                    Plasma membrane (Approved)
# SDHA                      Mitochondria (Supported)
# UQCRC1                    Mitochondria (Supported)
# ...                                            ...
# NAT8L                      Mitochondria (Approved)
# MCCD1                                          NaN
# PIGBOS1                                        NaN
# HTD2                      Mitochondria (Supported)
# RP11_469A15.2                                  NaN
#
# [1136 rows x 45 columns]

# %%
complexes = {
    "Complex I": "Complex I",
    "Complex II": "Complex II",
    "Complex III": "Complex III",
    "Complex IV": "Complex IV",
    "Complex V": "Complex V",
}

oxphos_genes = {}

for name, pattern in complexes.items():

    subset = mitocarta[
        mitocarta["MitoCarta3.0_MitoPathways"]
        .str.contains(pattern, case=False, na=False)
    ]

    genes = set()

    for symbol, row in subset.iterrows():

        # Official symbol
        genes.add(symbol.upper())

        # Synonyms
        if pd.notna(row["Synonyms"]):
            genes.update(
                syn.strip().upper()
                for syn in row["Synonyms"].split("|")
                if syn.strip()
            )

    oxphos_genes[name] = genes
    
for complex_name, genes in oxphos_genes.items():
    print(f"{complex_name}: {len(genes)} identifiers")
    print(sorted(list(genes))[:10], "\n")
# Out:
# Complex I: 561 identifiers
# ['-', '0710008D09RIK', '2010204O13RIK', '2310061C15RIK', '2P1', '6330578E17RIK', 'ACAD9', 'ACN9', 'ACP', 'ACP1']
#
# Complex II: 124 identifiers
# ['0710008D09RIK', '2010204O13RIK', 'ACN9', 'BA6B20.2', 'BCS', 'BCS1', 'BCS1L', 'BFZB', 'BJS', 'C11ORF79']
#
# Complex III: 82 identifiers
# ['0710008D09RIK', '2010204O13RIK', 'BA6B20.2', 'BCS', 'BCS1', 'BCS1L', 'BFZB', 'BJS', 'C11ORF83', 'C20ORF44']
#
# Complex IV: 179 identifiers
# ['-', '2310061C15RIK', '6330578E17RIK', 'APLCC', 'APOP', 'APOP1', 'APOPT1', 'BRP17', 'C12ORF62', 'C14ORF112']
#
# Complex V: 107 identifiers
# ['6.8PL', 'APT5H', 'ATP11', 'ATP11P', 'ATP12', 'ATP12P', 'ATP5', 'ATP5A', 'ATP5A1', 'ATP5AL2']

# %%
from pathlib import Path

subtypes = ["classical", "proneural", "idh", "mesenchymal"]

input_dir = Path("../data/processed/diff")
output_dir = Path("../data/processed/oxphos")
output_dir.mkdir(exist_ok=True)

for subtype in subtypes:

    df = pd.read_csv(
        input_dir / f"{subtype}_combined.csv",
        index_col=0
    )

    # Ensure uppercase gene names
    df.index = df.index.str.upper()

    for complex_name, genes in oxphos_genes.items():

        subset = df.loc[
            df.index.intersection(genes)
        ].sort_index()

        filename = (
            f"{subtype}_"
            f"{complex_name.lower().replace(' ', '_')}.csv"
        )

        subset.to_csv(output_dir / filename)

        print(f"{filename}: {subset.shape[0]} genes")
# Out:
# classical_complex_i.csv: 128 genes
# classical_complex_ii.csv: 22 genes
# classical_complex_iii.csv: 16 genes
# classical_complex_iv.csv: 45 genes
# classical_complex_v.csv: 6 genes
# proneural_complex_i.csv: 128 genes
# proneural_complex_ii.csv: 22 genes
# proneural_complex_iii.csv: 16 genes
# proneural_complex_iv.csv: 45 genes
# proneural_complex_v.csv: 6 genes
# idh_complex_i.csv: 128 genes
# idh_complex_ii.csv: 22 genes
# idh_complex_iii.csv: 16 genes
# idh_complex_iv.csv: 45 genes
# idh_complex_v.csv: 6 genes
# mesenchymal_complex_i.csv: 128 genes
# mesenchymal_complex_ii.csv: 22 genes
# mesenchymal_complex_iii.csv: 16 genes
# mesenchymal_complex_iv.csv: 45 genes
# mesenchymal_complex_v.csv: 6 genes
