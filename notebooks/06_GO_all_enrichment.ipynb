# %%
import sys
sys.path.append("../src")

import GOenrichment as ge
import importlib

importlib.reload(ge)

files = {
    "Proneural": "../data/interim/proneural_rna_diff.csv",
    "Classical": "../data/interim/classical_rna_diff.csv",
    "Mesenchymal": "../data/interim/mesenchymal_rna_diff.csv",
    "IDH": "../data/interim/idh_rna_diff.csv"
}

# %%
for subtype, file in files.items():
    ge.analyze_subtype(
        file,
        subtype,
        direction="split"
    )
# Out:
# Proneural: BP UP
# Proneural: BP DOWN
# Proneural: CC UP
# Proneural: CC DOWN
# Proneural: MF UP
# Proneural: MF DOWN
# Classical: BP UP
# Classical: BP DOWN
# Classical: CC UP
# Classical: CC DOWN
# Classical: MF UP
# Classical: MF DOWN
# Mesenchymal: BP UP
# Mesenchymal: BP DOWN
# Mesenchymal: CC UP
# Mesenchymal: CC DOWN
# Mesenchymal: MF UP
# Mesenchymal: MF DOWN
# IDH: BP UP
# IDH: BP DOWN
# IDH: CC UP
# IDH: CC DOWN
# IDH: MF UP
# IDH: MF DOWN

# %%
for subtype, file in files.items():
    ge.analyze_subtype(
        file,
        subtype,
        direction="combined"
    )
# Out:
# Proneural: BP
# Proneural: CC
# Proneural: MF
# Classical: BP
# Classical: CC
# Classical: MF
# Mesenchymal: BP
# Mesenchymal: CC
# Mesenchymal: MF
# IDH: BP
# IDH: CC
# IDH: MF

# %%
go_combined = {}

for subtype, file in files.items():
    go_combined[subtype] = ge.analyze_subtype(
        file,
        subtype,
        direction="combined"
    )


# Shared by ALL 4 subtypes
bp1 = ge.build_go_matrix(go_combined, "BP", n_terms=20, min_subtypes=4)

# Shared by at least 3 subtypes (recommended)
bp2 = ge.build_go_matrix(go_combined, "BP", n_terms=20, min_subtypes=3)

# Shared by at least 2 subtypes
bp3 = ge.build_go_matrix(go_combined, "BP", n_terms=20, min_subtypes=2)

ge.plot_go_comparison(bp1, "GO Biological Process") 
ge.plot_go_comparison(bp2, "GO Biological Process")
ge.plot_go_comparison(bp3, "GO Biological Process")
# Out:
# Proneural: BP
# Proneural: CC
# Proneural: MF
# Classical: BP
# Classical: CC
# Classical: MF
# Mesenchymal: BP
# Mesenchymal: CC
# Mesenchymal: MF
# IDH: BP
# IDH: CC
# IDH: MF

# %%
cc = ge.build_go_matrix(
    go_combined,
    ontology="CC",
    min_subtypes=4
)
ge.plot_go_comparison(cc, "Shared GO Cellular Component")

# %%
mf = ge.build_go_matrix(
    go_combined,
    ontology="MF",
    min_subtypes=4
)
ge.plot_go_comparison(mf, "Shared GO Molecular Function")
